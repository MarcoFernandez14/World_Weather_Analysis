# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
import requests
import time
from datetime import datetime
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
# URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc})
                          # "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | katsuura
# Processing Record 2 of Set 1 | saint-philippe
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | hay river
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | malinovoye ozero
# Processing Record 8 of Set 1 | hasaki
# Processing Record 9 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | eyrarbakki
# Processing Record 13 of Set 1 | lebu
# Processing Record 14 of Set 1 | vila velha
# Processing Record 15 of Set 1 | bayan
# Processing Record 16 of Set 1 | ahipara
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | sao filipe
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | piracuruca
# Processing Record 21 of Set 1 | sapele
# Processing Record 22 of Set 1 | souillac
# Processing Record 23 of Set 1 | sur
# Processing Record 24 of Set 1 | ondorhaan
# City not found. Skipping...
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | krutinka
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | mahebourg
# Processing Record 32 of Set 1 | leningradskiy
# Processing Record 33 of Set 1 | gold coast
# Processing Record 34 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | oranzherei
# Processing Record 37 of Set 1 | narsaq
# Processing Record 38 of Set 1 | nikolskoye
# Processing Record 39 of Set 1 | sisimiut
# Processing Record 40 of Set 1 | bengkulu
# Processing Record 41 of Set 1 | bandarbeyla
# Processing Record 42 of Set 1 | namatanai
# Processing Record 43 of Set 1 | jatai
# Processing Record 44 of Set 1 | georgetown
# Processing Record 45 of Set 1 | vanimo
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | yerbogachen
# Processing Record 48 of Set 1 | dakar
# Processing Record 49 of Set 1 | shyryayeve
# Processing Record 50 of Set 1 | weiser
# Processing Record 1 of Set 2 | port blair
# Processing Record 2 of Set 2 | port alfred
# Processing Record 3 of Set 2 | yar-sale
# Processing Record 4 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 5 of Set 2 | sao felix do xingu
# Processing Record 6 of Set 2 | mar del plata
# Processing Record 7 of Set 2 | kavaratti
# Processing Record 8 of Set 2 | flinders
# Processing Record 9 of Set 2 | mogadishu
# Processing Record 10 of Set 2 | mehamn
# Processing Record 11 of Set 2 | manzhouli
# Processing Record 12 of Set 2 | talnakh
# Processing Record 13 of Set 2 | armizonskoye
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | forbes
# Processing Record 16 of Set 2 | vaini
# Processing Record 17 of Set 2 | san quintin
# Processing Record 18 of Set 2 | fernie
# Processing Record 19 of Set 2 | pacific grove
# Processing Record 20 of Set 2 | honningsvag
# Processing Record 21 of Set 2 | lavrentiya
# Processing Record 22 of Set 2 | kerema
# Processing Record 23 of Set 2 | hermanus
# Processing Record 24 of Set 2 | pevek
# Processing Record 25 of Set 2 | bluff
# Processing Record 26 of Set 2 | kiruna
# Processing Record 27 of Set 2 | forrest city
# Processing Record 28 of Set 2 | santiago del estero
# Processing Record 29 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 2 | hithadhoo
# Processing Record 31 of Set 2 | chor
# Processing Record 32 of Set 2 | bahraich
# Processing Record 33 of Set 2 | boca del monte
# Processing Record 34 of Set 2 | marawi
# Processing Record 35 of Set 2 | nevelsk
# Processing Record 36 of Set 2 | tuktoyaktuk
# Processing Record 37 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 2 | umm kaddadah
# Processing Record 39 of Set 2 | rio claro
# Processing Record 40 of Set 2 | cape town
# Processing Record 41 of Set 2 | mersing
# Processing Record 42 of Set 2 | pocone
# Processing Record 43 of Set 2 | longyearbyen
# Processing Record 44 of Set 2 | maloshuyka
# City not found. Skipping...
# Processing Record 45 of Set 2 | lexington park
# Processing Record 46 of Set 2 | finote selam
# Processing Record 47 of Set 2 | iqaluit
# Processing Record 48 of Set 2 | agadez
# Processing Record 49 of Set 2 | nanortalik
# Processing Record 50 of Set 2 | esmeraldas
# Processing Record 1 of Set 3 | aksha
# Processing Record 2 of Set 3 | constitucion
# Processing Record 3 of Set 3 | east london
# Processing Record 4 of Set 3 | bodrum
# Processing Record 5 of Set 3 | sao joao da barra
# Processing Record 6 of Set 3 | pisco
# Processing Record 7 of Set 3 | galle
# Processing Record 8 of Set 3 | los llanos de aridane
# Processing Record 9 of Set 3 | belmonte
# Processing Record 10 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 11 of Set 3 | fortuna
# Processing Record 12 of Set 3 | natchez
# Processing Record 13 of Set 3 | sungairaya
# Processing Record 14 of Set 3 | marzuq
# Processing Record 15 of Set 3 | avera
# Processing Record 16 of Set 3 | abha
# Processing Record 17 of Set 3 | dandong
# Processing Record 18 of Set 3 | yellowknife
# Processing Record 19 of Set 3 | mogok
# Processing Record 20 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 3 | gashua
# Processing Record 22 of Set 3 | joensuu
# Processing Record 23 of Set 3 | pimentel
# Processing Record 24 of Set 3 | toftir
# City not found. Skipping...
# Processing Record 25 of Set 3 | kuzhener
# Processing Record 26 of Set 3 | yulara
# Processing Record 27 of Set 3 | hamilton
# Processing Record 28 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 3 | izhma
# Processing Record 30 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 3 | avarua
# Processing Record 33 of Set 3 | chuy
# Processing Record 34 of Set 3 | leh
# Processing Record 35 of Set 3 | cabo san lucas
# Processing Record 36 of Set 3 | faya
# Processing Record 37 of Set 3 | ribeira grande
# Processing Record 38 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 39 of Set 3 | nemuro
# Processing Record 40 of Set 3 | barrow
# Processing Record 41 of Set 3 | den helder
# Processing Record 42 of Set 3 | taua
# Processing Record 43 of Set 3 | eureka
# Processing Record 44 of Set 3 | bredasdorp
# Processing Record 45 of Set 3 | khatanga
# Processing Record 46 of Set 3 | shingu
# Processing Record 47 of Set 3 | huilong
# Processing Record 48 of Set 3 | husavik
# Processing Record 49 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 3 | comodoro rivadavia
# Processing Record 1 of Set 4 | athni
# Processing Record 2 of Set 4 | esperance
# Processing Record 3 of Set 4 | ilulissat
# Processing Record 4 of Set 4 | san carlos de bariloche
# Processing Record 5 of Set 4 | paamiut
# Processing Record 6 of Set 4 | aljezur
# Processing Record 7 of Set 4 | staryy nadym
# Processing Record 8 of Set 4 | majene
# Processing Record 9 of Set 4 | mnogovershinnyy
# Processing Record 10 of Set 4 | kaitangata
# Processing Record 11 of Set 4 | carnarvon
# Processing Record 12 of Set 4 | thompson
# Processing Record 13 of Set 4 | ust-barguzin
# Processing Record 14 of Set 4 | stephenville
# Processing Record 15 of Set 4 | luderitz
# Processing Record 16 of Set 4 | kristiinankaupunki
# Processing Record 17 of Set 4 | trelew
# Processing Record 18 of Set 4 | kurilsk
# Processing Record 19 of Set 4 | henties bay
# Processing Record 20 of Set 4 | kavieng
# Processing Record 21 of Set 4 | isangel
# Processing Record 22 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 4 | hajnowka
# Processing Record 24 of Set 4 | gilazi
# City not found. Skipping...
# Processing Record 25 of Set 4 | bhatkal
# Processing Record 26 of Set 4 | nouadhibou
# Processing Record 27 of Set 4 | acapulco
# Processing Record 28 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 29 of Set 4 | kaset sombun
# Processing Record 30 of Set 4 | krasnoselkup
# Processing Record 31 of Set 4 | yumen
# Processing Record 32 of Set 4 | lorengau
# Processing Record 33 of Set 4 | cherskiy
# Processing Record 34 of Set 4 | norman wells
# Processing Record 35 of Set 4 | westport
# Processing Record 36 of Set 4 | shache
# Processing Record 37 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 4 | coihaique
# Processing Record 39 of Set 4 | castelo do piaui
# Processing Record 40 of Set 4 | chapais
# Processing Record 41 of Set 4 | khatra
# Processing Record 42 of Set 4 | kyabram
# Processing Record 43 of Set 4 | praia da vitoria
# Processing Record 44 of Set 4 | santa fe
# Processing Record 45 of Set 4 | guerrero negro
# Processing Record 46 of Set 4 | uarini
# Processing Record 47 of Set 4 | zhaotong
# Processing Record 48 of Set 4 | marsh harbour
# Processing Record 49 of Set 4 | ransang
# Processing Record 50 of Set 4 | port hardy
# Processing Record 1 of Set 5 | ponta do sol
# Processing Record 2 of Set 5 | torbay
# Processing Record 3 of Set 5 | kenai
# Processing Record 4 of Set 5 | castro
# Processing Record 5 of Set 5 | lompoc
# Processing Record 6 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 5 | rehoboth
# Processing Record 8 of Set 5 | takoradi
# Processing Record 9 of Set 5 | tiznit
# Processing Record 10 of Set 5 | sioux lookout
# Processing Record 11 of Set 5 | tasiilaq
# Processing Record 12 of Set 5 | kahului
# Processing Record 13 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 5 | saldanha
# Processing Record 15 of Set 5 | mareeba
# Processing Record 16 of Set 5 | tiksi
# Processing Record 17 of Set 5 | beringovskiy
# Processing Record 18 of Set 5 | arraial do cabo
# Processing Record 19 of Set 5 | yate
# Processing Record 20 of Set 5 | santa rosa
# Processing Record 21 of Set 5 | oistins
# Processing Record 22 of Set 5 | hofn
# Processing Record 23 of Set 5 | kendal
# Processing Record 24 of Set 5 | mubende
# Processing Record 25 of Set 5 | buriti dos lopes
# Processing Record 26 of Set 5 | mitsamiouli
# Processing Record 27 of Set 5 | vardo
# Processing Record 28 of Set 5 | chokurdakh
# Processing Record 29 of Set 5 | new norfolk
# Processing Record 30 of Set 5 | amahai
# Processing Record 31 of Set 5 | agadir
# Processing Record 32 of Set 5 | kudahuvadhoo
# Processing Record 33 of Set 5 | gao
# Processing Record 34 of Set 5 | meulaboh
# Processing Record 35 of Set 5 | severo-kurilsk
# Processing Record 36 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 5 | peabiru
# Processing Record 38 of Set 5 | aklavik
# Processing Record 39 of Set 5 | noormarkku
# Processing Record 40 of Set 5 | muroto
# Processing Record 41 of Set 5 | northam
# Processing Record 42 of Set 5 | vrangel
# Processing Record 43 of Set 5 | virginia beach
# Processing Record 44 of Set 5 | tupancireta
# Processing Record 45 of Set 5 | namibe
# Processing Record 46 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 5 | bathurst
# Processing Record 48 of Set 5 | haines junction
# Processing Record 49 of Set 5 | abu samrah
# Processing Record 50 of Set 5 | awjilah
# Processing Record 1 of Set 6 | yarmouth
# Processing Record 2 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 6 | billings
# Processing Record 4 of Set 6 | harper
# Processing Record 5 of Set 6 | mungaoli
# Processing Record 6 of Set 6 | te anau
# Processing Record 7 of Set 6 | campbell river
# Processing Record 8 of Set 6 | ocos
# Processing Record 9 of Set 6 | saskylakh
# Processing Record 10 of Set 6 | dubrovka
# Processing Record 11 of Set 6 | jining
# Processing Record 12 of Set 6 | cidreira
# Processing Record 13 of Set 6 | luganville
# Processing Record 14 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 6 | larsnes
# Processing Record 16 of Set 6 | lebedinyy
# Processing Record 17 of Set 6 | tual
# Processing Record 18 of Set 6 | anloga
# Processing Record 19 of Set 6 | margate
# Processing Record 20 of Set 6 | laguna
# Processing Record 21 of Set 6 | manaus
# Processing Record 22 of Set 6 | thap than
# Processing Record 23 of Set 6 | bethel
# Processing Record 24 of Set 6 | alofi
# Processing Record 25 of Set 6 | russell
# Processing Record 26 of Set 6 | provideniya
# Processing Record 27 of Set 6 | lebanon
# Processing Record 28 of Set 6 | bambous virieux
# Processing Record 29 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 6 | upernavik
# Processing Record 31 of Set 6 | panambi
# Processing Record 32 of Set 6 | port elizabeth
# Processing Record 33 of Set 6 | okhotsk
# Processing Record 34 of Set 6 | koundara
# Processing Record 35 of Set 6 | rawson
# Processing Record 36 of Set 6 | pula
# Processing Record 37 of Set 6 | cubuk
# Processing Record 38 of Set 6 | gobabis
# Processing Record 39 of Set 6 | matay
# Processing Record 40 of Set 6 | san cristobal
# Processing Record 41 of Set 6 | kitimat
# Processing Record 42 of Set 6 | geraldton
# Processing Record 43 of Set 6 | faanui
# Processing Record 44 of Set 6 | zhigansk
# Processing Record 45 of Set 6 | klaksvik
# Processing Record 46 of Set 6 | el balyana
# City not found. Skipping...
# Processing Record 47 of Set 6 | bima
# Processing Record 48 of Set 6 | camacha
# Processing Record 49 of Set 6 | bonavista
# Processing Record 50 of Set 6 | chifeng
# Processing Record 1 of Set 7 | mount isa
# Processing Record 2 of Set 7 | tougue
# Processing Record 3 of Set 7 | cap malheureux
# Processing Record 4 of Set 7 | peniche
# Processing Record 5 of Set 7 | koprivnica
# Processing Record 6 of Set 7 | nome
# Processing Record 7 of Set 7 | tucuman
# Processing Record 8 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 9 of Set 7 | tatawin
# Processing Record 10 of Set 7 | saint-francois
# Processing Record 11 of Set 7 | macamic
# Processing Record 12 of Set 7 | heishan
# Processing Record 13 of Set 7 | jumla
# Processing Record 14 of Set 7 | magadan
# Processing Record 15 of Set 7 | dingle
# Processing Record 16 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 17 of Set 7 | tadine
# Processing Record 18 of Set 7 | hualmay
# Processing Record 19 of Set 7 | shepsi
# Processing Record 20 of Set 7 | nyurba
# Processing Record 21 of Set 7 | tuatapere
# Processing Record 22 of Set 7 | athabasca
# Processing Record 23 of Set 7 | lagoa
# Processing Record 24 of Set 7 | maniitsoq
# Processing Record 25 of Set 7 | dikson
# Processing Record 26 of Set 7 | pangnirtung
# Processing Record 27 of Set 7 | serdobsk
# Processing Record 28 of Set 7 | olafsvik
# Processing Record 29 of Set 7 | muisne
# Processing Record 30 of Set 7 | diego de almagro
# Processing Record 31 of Set 7 | puerto escondido
# Processing Record 32 of Set 7 | meadow lake
# Processing Record 33 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 34 of Set 7 | saint george
# Processing Record 35 of Set 7 | leshukonskoye
# Processing Record 36 of Set 7 | san patricio
# Processing Record 37 of Set 7 | barra do garcas
# Processing Record 38 of Set 7 | alexandria
# Processing Record 39 of Set 7 | victoria
# Processing Record 40 of Set 7 | martapura
# Processing Record 41 of Set 7 | buhe
# Processing Record 42 of Set 7 | kerki
# City not found. Skipping...
# Processing Record 43 of Set 7 | belaya gora
# Processing Record 44 of Set 7 | kununurra
# Processing Record 45 of Set 7 | inyonga
# Processing Record 46 of Set 7 | mount gambier
# Processing Record 47 of Set 7 | itambe
# Processing Record 48 of Set 7 | bugry
# Processing Record 49 of Set 7 | fairbanks
# Processing Record 50 of Set 7 | locri
# Processing Record 1 of Set 8 | saint-joseph
# Processing Record 2 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 3 of Set 8 | kloulklubed
# Processing Record 4 of Set 8 | nuuk
# Processing Record 5 of Set 8 | coahuayana
# Processing Record 6 of Set 8 | pacifica
# Processing Record 7 of Set 8 | cabinda
# Processing Record 8 of Set 8 | horsham
# Processing Record 9 of Set 8 | sungaipenuh
# Processing Record 10 of Set 8 | aloleng
# Processing Record 11 of Set 8 | salalah
# Processing Record 12 of Set 8 | kokopo
# Processing Record 13 of Set 8 | kruisfontein
# Processing Record 14 of Set 8 | toropets
# Processing Record 15 of Set 8 | flin flon
# Processing Record 16 of Set 8 | korla
# Processing Record 17 of Set 8 | murgab
# Processing Record 18 of Set 8 | fort nelson
# Processing Record 19 of Set 8 | wysokie mazowieckie
# Processing Record 20 of Set 8 | butler
# Processing Record 21 of Set 8 | bolobo
# Processing Record 22 of Set 8 | sitka
# Processing Record 23 of Set 8 | cumanayagua
# Processing Record 24 of Set 8 | kawalu
# Processing Record 25 of Set 8 | alice springs
# Processing Record 26 of Set 8 | kiama
# Processing Record 27 of Set 8 | touros
# Processing Record 28 of Set 8 | mednogorskiy
# Processing Record 29 of Set 8 | gunjur
# Processing Record 30 of Set 8 | ayagoz
# Processing Record 31 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 8 | camopi
# Processing Record 33 of Set 8 | mildura
# Processing Record 34 of Set 8 | filadelfia
# Processing Record 35 of Set 8 | rudnogorsk
# Processing Record 36 of Set 8 | sitges
# Processing Record 37 of Set 8 | ambilobe
# Processing Record 38 of Set 8 | umm lajj
# Processing Record 39 of Set 8 | morro bay
# Processing Record 40 of Set 8 | yablonovo
# Processing Record 41 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 8 | sijunjung
# Processing Record 43 of Set 8 | rimavska sobota
# Processing Record 44 of Set 8 | chik
# Processing Record 45 of Set 8 | aden
# Processing Record 46 of Set 8 | kusatsu
# Processing Record 47 of Set 8 | miranorte
# City not found. Skipping...
# Processing Record 48 of Set 8 | batagay
# Processing Record 49 of Set 8 | carutapera
# Processing Record 50 of Set 8 | kinablangan
# Processing Record 1 of Set 9 | hambantota
# Processing Record 2 of Set 9 | dhidhdhoo
# Processing Record 3 of Set 9 | ancud
# Processing Record 4 of Set 9 | vallenar
# Processing Record 5 of Set 9 | falun
# Processing Record 6 of Set 9 | villa guerrero
# Processing Record 7 of Set 9 | bathsheba
# Processing Record 8 of Set 9 | naze
# Processing Record 9 of Set 9 | bubaque
# Processing Record 10 of Set 9 | bereda
# Processing Record 11 of Set 9 | robertsport
# Processing Record 12 of Set 9 | tura
# Processing Record 13 of Set 9 | qazvin
# Processing Record 14 of Set 9 | sept-iles
# Processing Record 15 of Set 9 | la cruz
# Processing Record 16 of Set 9 | fiumicino
# Processing Record 17 of Set 9 | sudak
# Processing Record 18 of Set 9 | warmbad
# Processing Record 19 of Set 9 | sakaiminato
# Processing Record 20 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 21 of Set 9 | lazaro cardenas
# Processing Record 22 of Set 9 | kortkeros
# Processing Record 23 of Set 9 | lhuntshi
# City not found. Skipping...
# Processing Record 24 of Set 9 | cileunyi
# Processing Record 25 of Set 9 | moron
# Processing Record 26 of Set 9 | college
# Processing Record 27 of Set 9 | buala
# Processing Record 28 of Set 9 | namtsy
# Processing Record 29 of Set 9 | roma
# Processing Record 30 of Set 9 | lasa
# Processing Record 31 of Set 9 | tamalameque
# Processing Record 32 of Set 9 | kresek
# Processing Record 33 of Set 9 | bela
# Processing Record 34 of Set 9 | ebebiyin
# Processing Record 35 of Set 9 | dafeng
# Processing Record 36 of Set 9 | quibor
# Processing Record 37 of Set 9 | xai-xai
# Processing Record 38 of Set 9 | imeni poliny osipenko
# Processing Record 39 of Set 9 | bridgetown
# Processing Record 40 of Set 9 | poli
# Processing Record 41 of Set 9 | hit
# Processing Record 42 of Set 9 | durban
# Processing Record 43 of Set 9 | betsiamites
# Processing Record 44 of Set 9 | loa janan
# Processing Record 45 of Set 9 | kaeo
# Processing Record 46 of Set 9 | ballina
# Processing Record 47 of Set 9 | naryan-mar
# Processing Record 48 of Set 9 | auki
# Processing Record 49 of Set 9 | novikovo
# Processing Record 50 of Set 9 | chicama
# Processing Record 1 of Set 10 | sabha
# Processing Record 2 of Set 10 | quibdo
# Processing Record 3 of Set 10 | muborak
# Processing Record 4 of Set 10 | grindavik
# Processing Record 5 of Set 10 | north bend
# Processing Record 6 of Set 10 | canala
# Processing Record 7 of Set 10 | sulangan
# Processing Record 8 of Set 10 | egvekinot
# Processing Record 9 of Set 10 | vawkavysk
# Processing Record 10 of Set 10 | inverell
# Processing Record 11 of Set 10 | greymouth
# Processing Record 12 of Set 10 | winnemucca
# Processing Record 13 of Set 10 | elat
# Processing Record 14 of Set 10 | vikhorevka
# Processing Record 15 of Set 10 | beverley
# Processing Record 16 of Set 10 | zhuzhou
# Processing Record 17 of Set 10 | ayan
# Processing Record 18 of Set 10 | airai
# Processing Record 19 of Set 10 | pulandian
# Processing Record 20 of Set 10 | puerto colombia
# Processing Record 21 of Set 10 | harer
# Processing Record 22 of Set 10 | fukue
# Processing Record 23 of Set 10 | tailai
# Processing Record 24 of Set 10 | mwense
# Processing Record 25 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 26 of Set 10 | kuytun
# Processing Record 27 of Set 10 | kilrush
# Processing Record 28 of Set 10 | iguape
# Processing Record 29 of Set 10 | goalpara
# Processing Record 30 of Set 10 | muros
# Processing Record 31 of Set 10 | gamba
# Processing Record 32 of Set 10 | geresk
# City not found. Skipping...
# Processing Record 33 of Set 10 | beloha
# Processing Record 34 of Set 10 | kodiak
# Processing Record 35 of Set 10 | anadyr
# Processing Record 36 of Set 10 | san jose de rio tinto
# Processing Record 37 of Set 10 | whitefish
# Processing Record 38 of Set 10 | raudeberg
# Processing Record 39 of Set 10 | bowen
# Processing Record 40 of Set 10 | arlit
# Processing Record 41 of Set 10 | mbandaka
# Processing Record 42 of Set 10 | wad rawah
# Processing Record 43 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 44 of Set 10 | molteno
# Processing Record 45 of Set 10 | agropoli
# Processing Record 46 of Set 10 | nioro
# Processing Record 47 of Set 10 | rio grande
# Processing Record 48 of Set 10 | zhanatas
# City not found. Skipping...
# Processing Record 49 of Set 10 | upington
# Processing Record 50 of Set 10 | aranda de duero
# Processing Record 1 of Set 11 | taltal
# Processing Record 2 of Set 11 | vila do maio
# Processing Record 3 of Set 11 | slave lake
# Processing Record 4 of Set 11 | guanica
# Processing Record 5 of Set 11 | ambanja
# Processing Record 6 of Set 11 | cayenne
# Processing Record 7 of Set 11 | opobo
# City not found. Skipping...
# Processing Record 8 of Set 11 | constantine
# Processing Record 9 of Set 11 | chiredzi
# Processing Record 10 of Set 11 | tubuala
# Processing Record 11 of Set 11 | great bend
# Processing Record 12 of Set 11 | saint-leu
# Processing Record 13 of Set 11 | evanston
# Processing Record 14 of Set 11 | gangapur
# Processing Record 15 of Set 11 | mingguang
# Processing Record 16 of Set 11 | bara
# Processing Record 17 of Set 11 | jind
# Processing Record 18 of Set 11 | hemnesberget
# Processing Record 19 of Set 11 | tommot
# Processing Record 20 of Set 11 | thinadhoo
# Processing Record 21 of Set 11 | groa
# Processing Record 22 of Set 11 | udankudi
# Processing Record 23 of Set 11 | poselki
# Processing Record 24 of Set 11 | havelock
# Processing Record 25 of Set 11 | severobaykalsk
# Processing Record 26 of Set 11 | shenjiamen
# Processing Record 27 of Set 11 | chaman
# Processing Record 28 of Set 11 | dutse
# Processing Record 29 of Set 11 | belyy yar
# Processing Record 30 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 31 of Set 11 | iquitos
# Processing Record 32 of Set 11 | shimoda
# Processing Record 33 of Set 11 | tiquicheo
# Processing Record 34 of Set 11 | la romana
# Processing Record 35 of Set 11 | manzanillo
# Processing Record 36 of Set 11 | oda
# Processing Record 37 of Set 11 | alfeld
# Processing Record 38 of Set 11 | alekseyevsk
# Processing Record 39 of Set 11 | buchanan
# Processing Record 40 of Set 11 | adrar
# Processing Record 41 of Set 11 | mayumba
# Processing Record 42 of Set 11 | fort dodge
# Processing Record 43 of Set 11 | batemans bay
# Processing Record 44 of Set 11 | karratha
# Processing Record 45 of Set 11 | valley city
# Processing Record 46 of Set 11 | caracoli
# Processing Record 47 of Set 11 | asau
# Processing Record 48 of Set 11 | umba
# Processing Record 49 of Set 11 | oranjemund
# Processing Record 50 of Set 11 | matara
# Processing Record 1 of Set 12 | steinau
# Processing Record 2 of Set 12 | mao
# Processing Record 3 of Set 12 | lang son
# Processing Record 4 of Set 12 | dicabisagan
# Processing Record 5 of Set 12 | vedaranniyam
# City not found. Skipping...
# Processing Record 6 of Set 12 | roald
# Processing Record 7 of Set 12 | batagay-alyta
# Processing Record 8 of Set 12 | brae
# Processing Record 9 of Set 12 | andenes
# Processing Record 10 of Set 12 | mzimba
# Processing Record 11 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 12 of Set 12 | port hawkesbury
# Processing Record 13 of Set 12 | swan hill
# Processing Record 14 of Set 12 | vestmannaeyjar
# Processing Record 15 of Set 12 | broken hill
# Processing Record 16 of Set 12 | komsomolskiy
# Processing Record 17 of Set 12 | flagstaff
# Processing Record 18 of Set 12 | phuthaditjhaba
# Processing Record 19 of Set 12 | otradnoye
# Processing Record 20 of Set 12 | paliseul
# Processing Record 21 of Set 12 | ostrovnoy
# Processing Record 22 of Set 12 | missao velha
# Processing Record 23 of Set 12 | kemise
# Processing Record 24 of Set 12 | salinas
# Processing Record 25 of Set 12 | ucluelet
# Processing Record 26 of Set 12 | charters towers
# Processing Record 27 of Set 12 | palmer
# Processing Record 28 of Set 12 | moerai
# Processing Record 29 of Set 12 | qasigiannguit
# Processing Record 30 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 31 of Set 12 | hami
# Processing Record 32 of Set 12 | port lincoln
# Processing Record 33 of Set 12 | zhangye
# Processing Record 34 of Set 12 | birjand
# Processing Record 35 of Set 12 | ixtapa
# Processing Record 36 of Set 12 | nizwa
# Processing Record 37 of Set 12 | bang saphan
# Processing Record 38 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 39 of Set 12 | okha
# Processing Record 40 of Set 12 | chipinge
# Processing Record 41 of Set 12 | rocha
# Processing Record 42 of Set 12 | ye
# City not found. Skipping...
# Processing Record 43 of Set 12 | pangai
# Processing Record 44 of Set 12 | along
# Processing Record 45 of Set 12 | zeya
# Processing Record 46 of Set 12 | craig
# Processing Record 47 of Set 12 | maracacume
# Processing Record 48 of Set 12 | walvis bay
# Processing Record 49 of Set 12 | gambela
# Processing Record 50 of Set 12 | zhuhai
# Processing Record 1 of Set 13 | poum
# Processing Record 2 of Set 13 | mandalgovi
# Processing Record 3 of Set 13 | ardistan
# City not found. Skipping...
# Processing Record 4 of Set 13 | tigil
# Processing Record 5 of Set 13 | jalu
# Processing Record 6 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 13 | murray bridge
# Processing Record 9 of Set 13 | manaure
# Processing Record 10 of Set 13 | ketchikan
# Processing Record 11 of Set 13 | cam ranh
# Processing Record 12 of Set 13 | timbiqui
# Processing Record 13 of Set 13 | tashtagol
# Processing Record 14 of Set 13 | jalpa
# Processing Record 15 of Set 13 | smithers
# Processing Record 16 of Set 13 | havoysund
# Processing Record 17 of Set 13 | vao
# Processing Record 18 of Set 13 | vodnyy
# Processing Record 19 of Set 13 | tabou
# Processing Record 20 of Set 13 | rieti
# Processing Record 21 of Set 13 | dukat
# Processing Record 22 of Set 13 | sokol
# Processing Record 23 of Set 13 | altay
# Processing Record 24 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 25 of Set 13 | wum
# Processing Record 26 of Set 13 | tigzirt
# Processing Record 27 of Set 13 | somerset
# Processing Record 28 of Set 13 | kamaishi
# Processing Record 29 of Set 13 | drumheller
# Processing Record 30 of Set 13 | ishinomaki
# Processing Record 31 of Set 13 | vanderhoof
# Processing Record 32 of Set 13 | bama
# Processing Record 33 of Set 13 | yanchukan
# City not found. Skipping...
# Processing Record 34 of Set 13 | marsa matruh
# Processing Record 35 of Set 13 | salekhard
# Processing Record 36 of Set 13 | cabedelo
# Processing Record 37 of Set 13 | markala
# Processing Record 38 of Set 13 | caxito
# Processing Record 39 of Set 13 | samarai
# Processing Record 40 of Set 13 | kysyl-syr
# Processing Record 41 of Set 13 | todos santos
# Processing Record 42 of Set 13 | kieta
# Processing Record 43 of Set 13 | mucuri
# Processing Record 44 of Set 13 | likasi
# Processing Record 45 of Set 13 | challapata
# Processing Record 46 of Set 13 | karmana
# City not found. Skipping...
# Processing Record 47 of Set 13 | ngunut
# Processing Record 48 of Set 13 | sabya
# Processing Record 49 of Set 13 | port moresby
# Processing Record 50 of Set 13 | lata
# Processing Record 1 of Set 14 | hendersonville
# Processing Record 2 of Set 14 | yatou
# Processing Record 3 of Set 14 | payo
# Processing Record 4 of Set 14 | kushikino
# Processing Record 5 of Set 14 | ukhta
# Processing Record 6 of Set 14 | jinxiang
# Processing Record 7 of Set 14 | duluth
# Processing Record 8 of Set 14 | byron bay
# Processing Record 9 of Set 14 | coos bay
# Processing Record 10 of Set 14 | la rioja
# Processing Record 11 of Set 14 | portland
# Processing Record 12 of Set 14 | bressanone
# Processing Record 13 of Set 14 | rezina
# Processing Record 14 of Set 14 | ivdel
# Processing Record 15 of Set 14 | saint anthony
# Processing Record 16 of Set 14 | honggang
# Processing Record 17 of Set 14 | tazmalt
# Processing Record 18 of Set 14 | kumasi
# Processing Record 19 of Set 14 | oussouye
# Processing Record 20 of Set 14 | maceio
# Processing Record 21 of Set 14 | shilka
# Processing Record 22 of Set 14 | sundsvall
# Processing Record 23 of Set 14 | noumea
# Processing Record 24 of Set 14 | cadillac
# Processing Record 25 of Set 14 | izumo
# Processing Record 26 of Set 14 | okato
# Processing Record 27 of Set 14 | hongan
# City not found. Skipping...
# Processing Record 28 of Set 14 | chimbote
# Processing Record 29 of Set 14 | aripuana
# Processing Record 30 of Set 14 | zaragoza
# Processing Record 31 of Set 14 | singaparna
# Processing Record 32 of Set 14 | atar
# Processing Record 33 of Set 14 | binga
# Processing Record 34 of Set 14 | antalaha
# Processing Record 35 of Set 14 | rock sound
# Processing Record 36 of Set 14 | micheweni
# Processing Record 37 of Set 14 | chernyshevskiy
# Processing Record 38 of Set 14 | petatlan
# Processing Record 39 of Set 14 | tezu
# Processing Record 40 of Set 14 | mobaye
# Processing Record 41 of Set 14 | kuusamo
# Processing Record 42 of Set 14 | copiapo
# Processing Record 43 of Set 14 | omboue
# Processing Record 44 of Set 14 | morondava
# Processing Record 45 of Set 14 | straumen
# Processing Record 46 of Set 14 | mountain home
# Processing Record 47 of Set 14 | warrnambool
# Processing Record 48 of Set 14 | wamba
# Processing Record 49 of Set 14 | ghanzi
# Processing Record 50 of Set 14 | qitaihe
# Processing Record 1 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 2 of Set 15 | jujuy
# City not found. Skipping...
# Processing Record 3 of Set 15 | kenitra
# Processing Record 4 of Set 15 | mananjary
# Processing Record 5 of Set 15 | santiago
# Processing Record 6 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 8 of Set 15 | kuressaare
# Processing Record 9 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 10 of Set 15 | eldikan
# City not found. Skipping...
# Processing Record 11 of Set 15 | pyapon
# Processing Record 12 of Set 15 | tungkang
# City not found. Skipping...
# Processing Record 13 of Set 15 | mumford
# Processing Record 14 of Set 15 | tessalit
# Processing Record 15 of Set 15 | khani
# Processing Record 16 of Set 15 | cotonou
# Processing Record 17 of Set 15 | vega de alatorre
# Processing Record 18 of Set 15 | garachine
# Processing Record 19 of Set 15 | ulladulla
# Processing Record 20 of Set 15 | harnai
# City not found. Skipping...
# Processing Record 21 of Set 15 | axim
# City not found. Skipping...
# Processing Record 22 of Set 15 | teshie
# City not found. Skipping...
# Processing Record 23 of Set 15 | laon
# City not found. Skipping...
# Processing Record 24 of Set 15 | shihezi
# City not found. Skipping...
# Processing Record 25 of Set 15 | minab
# City not found. Skipping...
# Processing Record 26 of Set 15 | kahramanmaras
# City not found. Skipping...
# Processing Record 27 of Set 15 | wladyslawowo
# City not found. Skipping...
# Processing Record 28 of Set 15 | aykhal
# City not found. Skipping...
# Processing Record 29 of Set 15 | mapimi
# City not found. Skipping...
# Processing Record 30 of Set 15 | labuhan
# City not found. Skipping...
# Processing Record 31 of Set 15 | yamada
# City not found. Skipping...
# Processing Record 32 of Set 15 | sweetwater
# City not found. Skipping...
# Processing Record 33 of Set 15 | lodja
# City not found. Skipping...
# Processing Record 34 of Set 15 | wanning
# City not found. Skipping...
# Processing Record 35 of Set 15 | acarau
# City not found. Skipping...
# Processing Record 36 of Set 15 | sovetskiy
# City not found. Skipping...
# Processing Record 37 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 15 | ornskoldsvik
# City not found. Skipping...
# Processing Record 39 of Set 15 | ouargaye
# City not found. Skipping...
# Processing Record 40 of Set 15 | sabang
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 657

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Katsuura      JP  35.1333  140.3000     64.58        91
# 1    Saint-Philippe      RE -21.3585   55.7679     78.39        82
# 2           Mataura      NZ -46.1927  168.8643     40.23        94
# 3         Hay River      CA  60.8156 -115.7999     35.58        64
# 4            Atuona      PF  -9.8000 -139.0333     78.69        70
# 5            Albany      US  42.6001  -73.9662     69.33        26
# 6  Malinovoye Ozero      RU  51.6753   79.7825     60.78        24
# 7            Hasaki      JP  35.7333  140.8333     59.40        88
# 8           Qaanaaq      GL  77.4840  -69.3632     16.72        73
# 9             Kapaa      US  22.0752 -159.3190     73.72        88
#
#    Cloudiness  Wind Speed Current Description
# 0          85        4.34     overcast clouds
# 1          41        1.70          light rain
# 2          10        2.55           clear sky
# 3          75        1.14       broken clouds
# 4           8       21.21           clear sky
# 5           0        3.00           clear sky
# 6         100        6.20     overcast clouds
# 7          83        6.69       broken clouds
# 8           6        2.82           clear sky
# 9          20       17.27          few clouds

# %%
city_data_df["Lat"] = city_data_df["Lat"].map("{:.2f}".format)
city_data_df["Lng"] = city_data_df["Lng"].map("{:.2f}".format)
city_data_df.head(10)
# Out:
#                City Country     Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0          Katsuura      JP   35.13   140.30     64.58        91          85
# 1    Saint-Philippe      RE  -21.36    55.77     78.39        82          41
# 2           Mataura      NZ  -46.19   168.86     40.23        94          10
# 3         Hay River      CA   60.82  -115.80     35.58        64          75
# 4            Atuona      PF   -9.80  -139.03     78.69        70           8
# 5            Albany      US   42.60   -73.97     69.33        26           0
# 6  Malinovoye Ozero      RU   51.68    79.78     60.78        24         100
# 7            Hasaki      JP   35.73   140.83     59.40        88          83
# 8           Qaanaaq      GL   77.48   -69.36     16.72        73           6
# 9             Kapaa      US   22.08  -159.32     73.72        88          20
#
#    Wind Speed Current Description
# 0        4.34     overcast clouds
# 1        1.70          light rain
# 2        2.55           clear sky
# 3        1.14       broken clouds
# 4       21.21           clear sky
# 5        3.00           clear sky
# 6        6.20     overcast clouds
# 7        6.69       broken clouds
# 8        2.82           clear sky
# 9       17.27          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
